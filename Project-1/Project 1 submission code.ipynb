# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Analyse statewide participations after the new SAT format was released in March 2016.
# Find out states with lower-than-expected SAT participation rates and make recommendations to improve SAT participation rates as an employee of the College Board.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#pd.read_csv
sat_2017 = pd.read_csv("../data/sat_2017.csv")

# %%
act_2017 = pd.read_csv("../data/act_2017.csv")

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# ### Answer:
#
# _*ACT 2017 score*_
# - There are 52 rows that are the different states in USA participating in ACT 2017, it includes the National average too.
# - There are 7 columns in this dataset:
#  - State : the states in USA
#  - Participation: the ACT 2017 participation rate in each state
#  - English: ACT 2017 test scores on English
#  - Math: ACT 2017 test scores on Math
#  - Reading: ACT 2017 test scores on Reading
#  - Science: ACT 2017 test scores on Science
#  - Composite: ACT 2017 composite scores from the subjects tested
#
#
# _*SAT 2017 score*_
# - There are 51 rows that are the different states in USA participating in SAT 2017, it does not have the National average
# - There are 5 columns in this dataset:
#  - State : the states in USA
#  - Participation: the SAT 2017 participation rate in each state
#  - Evidence-Based Reading and Writing: SAT 2017 test scores on Evidence-Based Reading and Writing
#  - Math: SAT 2017 test scores on Math
#  - Total: Total SAT 2017 test scores of Evidence-Based Reading and Writing & Math

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
sat_2017.info()

# there are 51 samples/row
# shows dtype of each column
# no missing data

# participation is object dtype, should change into float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_2017.tail()
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           65%                                 561   541
# 47     Washington           64%                                 541   534
# 48  West Virginia           14%                                 558   528
# 49      Wisconsin            3%                                 642   649
# 50        Wyoming            3%                                 626   604
#
#     Total
# 46   1102
# 47   1075
# 48   1086
# 49   1291
# 50   1230

# %%
act_2017.info()

# there are 52 samples/row
# shows dtype of each column
# no missing data

#composite and participation is an object, should change into float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2017.tail()
# Wyoming has Composite score 20.2x so should be an error?
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %% [markdown]
# Answer:
# - Yes, by using describe() both datasets are complete and have no missing values.
# - In sat_2017 has an additional row for the National average.
# - In act_2017 DataFrame Wyoming has 20.2x for Composite score, there could be a typo error and will check further.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
act_2017[['English', 'Math', 'Reading', 'Science']].min()

# the min score for Science is very low compared to other Subjects for ACT 2017 and the source website
# Out:
# English    16.3
# Math       18.0
# Reading    18.1
# Science     2.3
# dtype: float64

# %%
act_2017[['Science']].sort_values(by='Science', ascending=True).head(2)
# find out the next minimum score
# Out:
#     Science
# 21      2.3
# 29     18.2

# %%
act_2017[['English', 'Math', 'Reading', 'Science']].max()
# Out:
# English    25.5
# Math       25.3
# Reading    26.0
# Science    24.9
# dtype: float64

# %%
sat_2017[['Evidence-Based Reading and Writing', 'Math']].min()

#the min score for Math is very low compared all the states in the source website
# Out:
# Evidence-Based Reading and Writing    482
# Math                                   52
# dtype: int64

# %%
sat_2017[['Math']].sort_values(by='Math', ascending=True).head(2)
# find out the next minimum score
# Out:
#     Math
# 20    52
# 8    468

# %%
sat_2017[['Evidence-Based Reading and Writing', 'Math']].max()
# Out:
# Evidence-Based Reading and Writing    644
# Math                                  651
# dtype: int64

# %% [markdown]
# Answer:
#
# _*ACT 2017 score*_
# 1. There are obvious issues with the observations.
# - The minimum mean score for ACT 2017 Science is 2.3 for Maryland which is an outlier and after checking the ACT source website, the ACT 2017 Science score for Maryland is 23.2
# What is the minimum possible value for each test/subtest?
# - English   : 16.3
# - Math      : 18.0
# - Reading   : 18.1
# - Science   : 18.2
#
# What is the maximum possible value?
# - English   : 25.5
# - Math      : 25.3
# - Reading   : 26.0
# - Science   : 24.9
#
# _*SAT 2017 score*_
# 1. There are obvious issues with the observations.
# - The minimum mean score for SAT 2017 Math is 52 for Maryland which is an outlier and after checking the SAT source website, the ACT 2017 Science score for Maryland is 524.
#
# What is the minimum possible value for each test/subtest?
# - Evidence-Based Reading and Writing:   482
# - Math                              :    468
#
# What is the maximum possible value?
# - Evidence-Based Reading and Writing:    644
# - Math                              :    651

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
act_2017[act_2017['Science']==2.3]

# the average of Maryland's ACT 2017 English, Math, Reading & Science do not result from the Composite Score
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
# https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf
# checked that the Average ACT 2017 score for Maryland is 23.2

# Assign ACT_2017 Maryland Science Score with 23.2

act_2017.loc[(act_2017['State']=='Maryland'),'Science']=23.2

# %%
# check ACT 2017 Maryland Science score is updated
act_2017[act_2017['State']=='Maryland']
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2      23.6

# %%
sat_2017[sat_2017['Math']==52]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
# Assign SAT 2017 Maryland Science Score with 524
# Based on source website 

sat_2017.loc[(sat_2017['State']=='Maryland'),'Math'] = 524

# %%
# check SAT 2017 math score is updated
sat_2017[sat_2017['State']=='Maryland']
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
# There is an error when checking act_2017.tail()
# composite value for Wyoming is 20.2x

act_2017[act_2017['Composite'] == '20.2x']
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
# there is only 1 Composite value with 20.2x while other value are strings with 1 decimal place
# most likely a typo error

act_2017['Composite'].value_counts()
# Out:
# 20.3     3
# 21.4     3
# 19.8     3
# 24.1     2
# 21.8     2
# 19.4     2
# 24.2     2
# 19.7     2
# 20.4     2
# 23.6     2
# 21.9     2
# 19.2     1
# 18.7     1
# 20.8     1
# 19.1     1
# 24.3     1
# 21.0     1
# 18.6     1
# 19.0     1
# 23.8     1
# 25.2     1
# 20.5     1
# 23.7     1
# 25.4     1
# 22.8     1
# 21.5     1
# 24.0     1
# 22.6     1
# 17.8     1
# 22.3     1
# 19.5     1
# 23.9     1
# 21.7     1
# 20.0     1
# 20.2x    1
# 20.7     1
# 25.5     1
# 22.0     1
# Name: Composite, dtype: int64

# %%
act_2017['Composite'].replace('20.2x', '20.2', inplace=True)

# replace permanent with inplace=True keyword

# %%
# checking
act_2017[act_2017['Composite'] == '20.2']
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017.dtypes

# participation is object dtype
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes

# participation is object dtype
# Composite is object dtype
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# ### Answer:
#
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?
#
# _*ACT 2017 score*_
# - Participation column is object dtype, it should be a numerical dtype, as it has a decimal place. it should be a float dtype
# - Composite column is object dtype,it should be a numerical dtype, as it has a decimal place. it should be a float dtype
#
# _*SAT 2017 score*_
# - Participation column is object dtype, it should be a numerical dtype, as it has a decimal place. it should be a float dtype

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
print(sat_2017['Participation'].dtype)
print(act_2017['Participation'].dtype)
# Out:
# object
# object

# %%
def convert_participation_to_numeric(df):
    return (float(df.rstrip('%')))

# participation is a string/object dtype
# remove '%' by .rstrip()
# convert to float dtype by float()
# result in the percentage value

# %%
sat_2017['Participation']=sat_2017['Participation'].map(convert_participation_to_numeric)
act_2017['Participation']=act_2017['Participation'].map(convert_participation_to_numeric)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# Composite is in string dtype, convert to float dtype

act_2017['Composite'] = act_2017['Composite'].astype('float')

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
sat_2017['Participation'].dtype
# Out:
# dtype('float64')

# %%
act_2017['Participation'].dtype
# Out:
# dtype('float64')

# %%
act_2017['Composite'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
# lowercase columns names
# use under scores as column name should not have spaces
# inplace = True for change to be permanent

sat_2017.rename(columns={'State':'state',
                         'Participation':'sat2017_part_rate',
                         'Evidence-Based Reading and Writing':'sat2017_erw',
                         'Math' : 'sat2017_math',
                         'Total': 'sat2017_total_score'
                        }, inplace=True)

# %%
#checking
sat_2017.columns
# Out:
# Index(['state', 'sat2017_part_rate', 'sat2017_erw', 'sat2017_math',
#        'sat2017_total_score'],
#       dtype='object')

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act_2017.rename(columns={'State':'state',
                         'Participation':'act2017_part_rate',
                         'English':'act2017_eng',
                         'Math' : 'act2017_math',
                         'Reading': 'act2017_read',
                         'Science':'act2017_sci',
                         'Composite':'act2017_com_score'
                        }, inplace=True)

# %%
#checking

act_2017.columns
# Out:
# Index(['state', 'act2017_part_rate', 'act2017_eng', 'act2017_math',
#        'act2017_read', 'act2017_sci', 'act2017_com_score'],
#       dtype='object')

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state             |object |act_2017|The different states in USA participating in ACT 2017|
# |act2017_part_rate |float  |act_2017|The percent of participation in ACT 2017 by state           |
# |act2017_eng       |float  |act_2017|The mean score of English in ACT 2017 by state               |
# |act2017_math      |float  |act_2017|The mean score of Mathematics in ACT 2017 by state           |
# |act2017_read      |float  |act_2017|The mean score of Reading in ACT 2017 by state               |
# |act2017_sci       |float  |act_2017|The mean score of Science in ACT 2017 by state               |
# |act2017_com_score|float  |act_2017|The composite score of English, Mathematics, Reading and Science in ACT 2017 by state|
# |state             |object |sat_2017|The different states in USA participating in SAT 2017|
# |sat2017_part_rate |float  |sat_2017|The percent of participation in SAT 2017 by state             |
# |sat2017_erw       |int    |sat_2017|The mean score of Evidence-Based Reading and Writing in SAT 2017 by state|
# |sat2017_math      |int    |sat_2017|The mean score of Mathematics in SAT 2017 by state           |
# |sat2017_total_score|int |sat_2017|The total score of Evidence-Based Reading and Writing; and Mathematics in SAT 2017 by state|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
act_2017.head()
# Out:
#       state  act2017_part_rate  act2017_eng  act2017_math  act2017_read  \
# 0  National               60.0         20.3          20.7          21.4
# 1   Alabama              100.0         18.9          18.4          19.7
# 2    Alaska               65.0         18.7          19.8          20.4
# 3   Arizona               62.0         18.6          19.8          20.1
# 4  Arkansas              100.0         18.9          19.0          19.7
#
#    act2017_sci  act2017_com_score
# 0         21.0               21.0
# 1         19.4               19.2
# 2         19.9               19.8
# 3         19.8               19.7
# 4         19.5               19.4

# %%
# drop row 0

act_2017.drop(index=0, inplace=True)

# %%
#checking 
act_2017.head()
# Out:
#         state  act2017_part_rate  act2017_eng  act2017_math  act2017_read  \
# 1     Alabama              100.0         18.9          18.4          19.7
# 2      Alaska               65.0         18.7          19.8          20.4
# 3     Arizona               62.0         18.6          19.8          20.1
# 4    Arkansas              100.0         18.9          19.0          19.7
# 5  California               31.0         22.5          22.7          23.1
#
#    act2017_sci  act2017_com_score
# 1         19.4               19.2
# 2         19.9               19.8
# 3         19.8               19.7
# 4         19.5               19.4
# 5         22.2               22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
combined_2017 = act_2017.merge(sat_2017, on='state')

# %%
combined_2017.head()
# Out:
#         state  act2017_part_rate  act2017_eng  act2017_math  act2017_read  \
# 0     Alabama              100.0         18.9          18.4          19.7
# 1      Alaska               65.0         18.7          19.8          20.4
# 2     Arizona               62.0         18.6          19.8          20.1
# 3    Arkansas              100.0         18.9          19.0          19.7
# 4  California               31.0         22.5          22.7          23.1
#
#    act2017_sci  act2017_com_score  sat2017_part_rate  sat2017_erw  \
# 0         19.4               19.2                5.0          593
# 1         19.9               19.8               38.0          547
# 2         19.8               19.7               30.0          563
# 3         19.5               19.4                3.0          614
# 4         22.2               22.8               53.0          531
#
#    sat2017_math  sat2017_total_score
# 0           572                 1165
# 1           533                 1080
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
combined_2017.to_csv('..\data\combined_2017.csv', index=False)

# %%
pd.read_csv("..\data\combined_2017.csv").head()

#checking the file
# Out:
#         state  act2017_part_rate  act2017_eng  act2017_math  act2017_read  \
# 0     Alabama              100.0         18.9          18.4          19.7
# 1      Alaska               65.0         18.7          19.8          20.4
# 2     Arizona               62.0         18.6          19.8          20.1
# 3    Arkansas              100.0         18.9          19.0          19.7
# 4  California               31.0         22.5          22.7          23.1
#
#    act2017_sci  act2017_com_score  sat2017_part_rate  sat2017_erw  \
# 0         19.4               19.2                5.0          593
# 1         19.9               19.8               38.0          547
# 2         19.8               19.7               30.0          563
# 3         19.5               19.4                3.0          614
# 4         22.2               22.8               53.0          531
#
#    sat2017_math  sat2017_total_score
# 0           572                 1165
# 1           533                 1080
# ...

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %% [markdown]
# ##### 1. Read data for sat_2018.csv and act_2018_updated.csv

# %%
# import sat_2018.csv from file path
sat_2018 = pd.read_csv("../data/sat_2018.csv")

# %%
# import act_2018_updated.csv from file path
act_2018 = pd.read_csv('../data/act_2018_updated.csv')

# %% [markdown]
# ##### 2.Display Data to understand contents of data
# display head & tail of dataframe

# %%
sat_2018.head(5)

# same number of columns as sat_2017 dataframe
# also need to remove '%' from Participation column and convert dtype to float
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2018.tail(5)
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           68%                                 567   550
# 47     Washington           69%                                 543   538
# 48  West Virginia           28%                                 513   486
# 49      Wisconsin            3%                                 641   653
# 50        Wyoming            3%                                 633   625
#
#     Total
# 46   1117
# 47   1081
# 48    999
# 49   1294
# 50   1257

# %%
act_2018.head(5)

# same number of columns as sat_2017 dataframe
# also need to change Participation column to float
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
act_2018.tail(5)
# Out:
#             State  Percentage of Students Tested  Average Composite Score  \
# 46       Virginia                             24                     23.9
# 47     Washington                             24                     22.2
# 48  West Virginia                             65                     20.3
# 49      Wisconsin                            100                     20.5
# 50        Wyoming                            100                     20.0
#
#     Average English Score  Average Math Score  Average Reading Score  \
# 46                   23.8                23.3                   24.7
# 47                   21.4                22.2                   22.7
# 48                   19.8                19.4                   21.3
# 49                   19.8                20.3                   20.6
# 50                   19.0                19.7                   20.6
#
#     Average Science Score
# 46                   23.5
# 47                   22.0
# ...

# %% [markdown]
# ##### 3.Describe Data, this applies to numerical dtypes in dataframes
# - will show the mean, max, min...etc
# - Note: count column refers to available values, if count , there are missing values

# %%
sat_2018.describe()

# there are 51 count for each column, hence no missing value
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
act_2018.describe()

# there are 51 count for each column, hence no missing value
# Out:
#        Percentage of Students Tested  Average Composite Score  \
# count                      51.000000                51.000000
# mean                       61.647059                21.486275
# std                        34.080976                 2.106278
# min                         7.000000                17.700000
# 25%                        28.500000                19.950000
# 50%                        66.000000                21.300000
# 75%                       100.000000                23.550000
# max                       100.000000                25.600000
#
#        Average English Score  Average Math Score  Average Reading Score  \
# count              51.000000           51.000000              51.000000
# mean               20.988235           21.125490              22.015686
# std                 2.446356            2.035765               2.167245
# min                16.600000           17.800000              18.000000
# ...

# %% [markdown]
# ##### 4. Understand the dtype
# -check the dtype of the columns : int, float or object/string
# -are there dtypes that should be changed? E.g object to float

# %%
act_2018.info()

# 'Percentage of Students Tested' column is int
# will need to convert dtype from int to float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     int64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# ### 5. convert dtype in act_2018 dataframe from int to float

# %%
# check that the column is int64 instead of float
act_2018['Percentage of Students Tested'].head()
# Out:
# 0    100
# 1     33
# 2     66
# 3    100
# 4     27
# Name: Percentage of Students Tested, dtype: int64

# %%
#convert to float and decimal places to reflect percentage
act_2018['Percentage of Students Tested'] = act_2018['Percentage of Students Tested'].astype('float')

# %%
act_2018['Percentage of Students Tested'].head()
# Out:
# 0    100.0
# 1     33.0
# 2     66.0
# 3    100.0
# 4     27.0
# Name: Percentage of Students Tested, dtype: float64

# %% [markdown]
# ### 6. convert dtype in sat_2018 dataaframe from object to float & int to float

# %%
sat_2018['Participation'].head()

# also in string format with '%' in 2017 dataset
# Out:
# 0     6%
# 1    43%
# 2    29%
# 3     5%
# 4    60%
# Name: Participation, dtype: object

# %%
# use the function created earlier to convert the participation rate to numeric
# sat_2018['Participation'] is a string/object dtype

sat_2018['Participation']=sat_2018['Participation'].map(convert_participation_to_numeric)

# %% [markdown]
# ### 7. Rename Columns
# - has to be lowercase
# - has to be unique to sat_2018 & act_2018 dataset as will be combining with 2017 dataset later
# - use underscores as column name should not have spaces

# %%
# find the current column names for act_2018

act_2018.columns
# Out:
# Index(['State', 'Percentage of Students Tested', 'Average Composite Score',
#        'Average English Score', 'Average Math Score', 'Average Reading Score',
#        'Average Science Score'],
#       dtype='object')

# %%
# use dictionary to rename column names
# inplace = True, to make changes permanent

act_2018.rename(columns={'State':'state',
                         'Percentage of Students Tested':'act2018_part_rate',
                         'Average English Score':'act2018_eng',
                         'Average Math Score' : 'act2018_math',
                         'Average Reading Score': 'act2018_read',
                         'Average Science Score':'act2018_sci',
                         'Average Composite Score':'act2018_com_score'
                        }, inplace=True)

# %%
#checking they are lower case

act_2018.columns
# Out:
# Index(['state', 'act2018_part_rate', 'act2018_com_score', 'act2018_eng',
#        'act2018_math', 'act2018_read', 'act2018_sci'],
#       dtype='object')

# %%
# find the current column names for sat_2018

sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
# rename column names
# inplace = True, to make changes permanent

sat_2018.rename(columns={'State':'state',
                         'Participation':'sat2018_part_rate',
                         'Evidence-Based Reading and Writing':'sat2018_erw',
                         'Math' : 'sat2018_math',
                         'Total': 'sat2018_total_score'
                        }, inplace=True)

# %%
# checking they are lowercase
sat_2018.columns
# Out:
# Index(['state', 'sat2018_part_rate', 'sat2018_erw', 'sat2018_math',
#        'sat2018_total_score'],
#       dtype='object')

# %% [markdown]
# ### 8. Create a data dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state             |object |act_2018|The different states in USA participating in ACT 2018|
# |act2018_part_rate |float  |act_2018|The percent of participation in ACT 2018 by state            |
# |act2018_com_score |float  |act_2018|The composite score of English, Mathematics, Reading and Science in ACT 2018 by state|
# |act2018_eng       |float  |act_2018|The mean score of English in ACT 2018 by state                |
# |act2018_math      |float  |act_2018|The mean score of Mathematics in ACT 2018 by state           |
# |act2018_read      |float  |act_2018|The mean score of Reading in ACT 2018 by state               |
# |act2018_sci       |float  |act_2018|The mean score of Science in ACT 2018 by state               |
# |state              |object |sat_2018|The different states in USA participating in SAT 2018|
# |sat2018_part_rate  |float  |sat_2018|The percent of participation in SAT 2018 by state            |
# |sat2018_erw        |int   |sat_2018|The mean score of Evidence-Based Reading and Writing in SAT 2018 by state|
# |sat2018_math       |int    |sat_2018|The mean score of Mathematics in SAT 2018 by state           |
# |sat2018_total_score|int   |sat_2018|The total score of Evidence-Based Reading and Writing; and Mathematics in SAT 2018 by state|

# %% [markdown]
# ### 9. Merge Datasets
# - Join the 2018 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# use state as the key
combined_2018 = act_2018.merge(sat_2018, on='state')

# %%
combined_2018.head()
# Out:
#         state  act2018_part_rate  act2018_com_score  act2018_eng  \
# 0     Alabama              100.0               19.1         18.9
# 1      Alaska               33.0               20.8         19.8
# 2     Arizona               66.0               19.2         18.2
# 3    Arkansas              100.0               19.4         19.1
# 4  California               27.0               22.7         22.5
#
#    act2018_math  act2018_read  act2018_sci  sat2018_part_rate  sat2018_erw  \
# 0          18.3          19.6         19.0                6.0          595
# 1          20.6          21.6         20.7               43.0          562
# 2          19.4          19.5         19.2               29.0          577
# 3          18.9          19.7         19.4                5.0          592
# 4          22.5          23.0         22.1               60.0          540
#
#    sat2018_math  sat2018_total_score
# 0           571                 1166
# 1           544                 1106
# ...

# %%
# save the csv file to data folder
combined_2018.to_csv('..\data\combined_2018.csv', index=False)

# %%
#checking
pd.read_csv("..\data\combined_2018.csv").head()
# Out:
#         state  act2018_part_rate  act2018_com_score  act2018_eng  \
# 0     Alabama              100.0               19.1         18.9
# 1      Alaska               33.0               20.8         19.8
# 2     Arizona               66.0               19.2         18.2
# 3    Arkansas              100.0               19.4         19.1
# 4  California               27.0               22.7         22.5
#
#    act2018_math  act2018_read  act2018_sci  sat2018_part_rate  sat2018_erw  \
# 0          18.3          19.6         19.0                6.0          595
# 1          20.6          21.6         20.7               43.0          562
# 2          19.4          19.5         19.2               29.0          577
# 3          18.9          19.7         19.4                5.0          592
# 4          22.5          23.0         22.1               60.0          540
#
#    sat2018_math  sat2018_total_score
# 0           571                 1166
# 1           544                 1106
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = combined_2017.merge(combined_2018, on='state')

# none of columns have identical names
# merge using keyword on='state'

# %%
#checking
final.head()
# Out:
#         state  act2017_part_rate  act2017_eng  act2017_math  act2017_read  \
# 0     Alabama              100.0         18.9          18.4          19.7
# 1      Alaska               65.0         18.7          19.8          20.4
# 2     Arizona               62.0         18.6          19.8          20.1
# 3    Arkansas              100.0         18.9          19.0          19.7
# 4  California               31.0         22.5          22.7          23.1
#
#    act2017_sci  act2017_com_score  sat2017_part_rate  sat2017_erw  \
# 0         19.4               19.2                5.0          593
# 1         19.9               19.8               38.0          547
# 2         19.8               19.7               30.0          563
# 3         19.5               19.4                3.0          614
# 4         22.2               22.8               53.0          531
#
#    sat2017_math  ...  act2018_part_rate  act2018_com_score  act2018_eng  \
# ...

# %%
# save the csv file to data folder
final.to_csv('../data/final.csv', index=False)

# %%
#checking if the saved file ccan be read
final = pd.read_csv("../data/final.csv")
final.head()
# Out:
#         state  act2017_part_rate  act2017_eng  act2017_math  act2017_read  \
# 0     Alabama              100.0         18.9          18.4          19.7
# 1      Alaska               65.0         18.7          19.8          20.4
# 2     Arizona               62.0         18.6          19.8          20.1
# 3    Arkansas              100.0         18.9          19.0          19.7
# 4  California               31.0         22.5          22.7          23.1
#
#    act2017_sci  act2017_com_score  sat2017_part_rate  sat2017_erw  \
# 0         19.4               19.2                5.0          593
# 1         19.9               19.8               38.0          547
# 2         19.8               19.7               30.0          563
# 3         19.5               19.4                3.0          614
# 4         22.2               22.8               53.0          531
#
#    sat2017_math  ...  act2018_part_rate  act2018_com_score  act2018_eng  \
# ...

# %% [markdown]
# ### Create Data Dictionary for final dataset
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state             |object |final|The different states in USA participating in ACT & SAT|
# |act2017_part_rate |float  |final|The percent of participation in ACT 2017 by state           |
# |act2017_eng       |float  |final|The mean score of English in ACT 2017 by state               |
# |act2017_math      |float  |final|The mean score of Mathematics in ACT 2017 by state           |
# |act2017_read      |float  |final|The mean score of Reading in ACT 2017 by state               |
# |act2017_sci       |float  |final|The mean score of Science in ACT 2017 by state               |
# |act2017_com_score|float  |final|The composite score of English, Mathematics, Reading and Science in ACT 2017 by state|
# |sat2017_part_rate |float  |final|The percent of participation in SAT 2017 by state             |
# |sat2017_erw       |int    |final|The mean score of Evidence-Based Reading and Writing in SAT 2017 by state|
# |sat2017_math      |int    |final|The mean score of Mathematics in SAT 2017 by state           |
# |sat2017_total_score|int   |final|The total score of Evidence-Based Reading and Writing; and Mathematics in SAT 2017 by state|
# |act2018_part_rate |float  |final|The percent of participation in ACT 2018 by state            |
# |act2018_com_score |float  |final|The composite score of English, Mathematics, Reading and Science in ACT 2018 by state|
# |act2018_eng       |float  |final|The mean score of English in ACT 2018 by state                |
# |act2018_math      |float  |final|The mean score of Mathematics in ACT 2018 by state           |
# |act2018_read      |float  |final|The mean score of Reading in ACT 2018 by state               |
# |act2018_sci       |float  |final|The mean score of Science in ACT 2018 by state               |
# |sat2018_part_rate  |float  |final|The percent of participation in SAT 2018 by state            |
# |sat2018_erw        |int   |final|The mean score of Evidence-Based Reading and Writing in SAT 2018 by state|
# |sat2018_math       |int    |final|The mean score of Mathematics in SAT 2018 by state           |
# |sat2018_total_score|int   |final|The total score of Evidence-Based Reading and Writing; and Mathematics in SAT 2018 by state|

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().transpose()

# describe() only for numeric features
# Out:
#                      count         mean        std    min      25%     50%  \
# act2017_part_rate     51.0    65.254902  32.140842    8.0    31.00    69.0
# act2017_eng           51.0    20.931373   2.353677   16.3    19.00    20.7
# act2017_math          51.0    21.182353   1.981989   18.0    19.40    20.9
# act2017_read          51.0    22.013725   2.067271   18.1    20.45    21.8
# act2017_sci           51.0    21.450980   1.739353   18.2    19.95    21.3
# act2017_com_score     51.0    21.519608   2.020695   17.8    19.80    21.4
# sat2017_part_rate     51.0    39.803922  35.276632    2.0     4.00    38.0
# sat2017_erw           51.0   569.117647  45.666901  482.0   533.50   559.0
# sat2017_math          51.0   556.882353  47.121395  468.0   523.50   548.0
# sat2017_total_score   51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act2018_part_rate     51.0    61.647059  34.080976    7.0    28.50    66.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def calculate_std_deviation(x):
    length = len(x)
    mean = (sum(x)*1.0)/len(x)
    total_sum = 0
    for i in range(length):
        total_sum += (x[i] -mean)**2
        before_squareroot = total_sum*1.0/length
    return (before_squareroot)**0.5

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {column:calculate_std_deviation(final[column]) for column in final if column!='state'}

# %%
sd
# Out:
# {'act2017_part_rate': 31.824175751231806,
#  'act2017_eng': 2.3304876369363363,
#  'act2017_math': 1.9624620273436781,
#  'act2017_read': 2.0469029314842646,
#  'act2017_sci': 1.7222161451443676,
#  'act2017_com_score': 2.000786081581989,
#  'sat2017_part_rate': 34.92907076664508,
#  'sat2017_erw': 45.21697020437866,
#  'sat2017_math': 46.65713364485503,
#  'sat2017_total_score': 91.58351056778743,
#  'act2018_part_rate': 33.745194881997506,
#  'act2018_com_score': 2.0855261815801147,
#  'act2018_eng': 2.4222536143202795,
#  'act2018_math': 2.015707255555717,
#  'act2018_read': 2.145891884510421,
#  'act2018_sci': 1.8516885484833543,
#  'sat2018_part_rate': 36.946619223539415,
#  'sat2018_erw': 47.03460978357609,
#  'sat2018_math': 47.30194550378352,
#  'sat2018_total_score': 93.22742384464433}

# %%
# use python standard deviation method on columns

final[['act2017_part_rate', 'act2017_eng', 'act2017_math',
       'act2017_read', 'act2017_sci', 'act2017_com_score', 'sat2017_part_rate',
       'sat2017_erw', 'sat2017_math', 'sat2017_total_score',
       'act2018_part_rate', 'act2018_com_score', 'act2018_eng', 'act2018_math',
       'act2018_read', 'act2018_sci', 'sat2018_part_rate', 'sat2018_erw',
       'sat2018_math', 'sat2018_total_score']].std()
# Out:
# act2017_part_rate      32.140842
# act2017_eng             2.353677
# act2017_math            1.981989
# act2017_read            2.067271
# act2017_sci             1.739353
# act2017_com_score       2.020695
# sat2017_part_rate      35.276632
# sat2017_erw            45.666901
# sat2017_math           47.121395
# sat2017_total_score    92.494812
# act2018_part_rate      34.080976
# act2018_com_score       2.106278
# act2018_eng             2.446356
# act2018_math            2.035765
# act2018_read            2.167245
# act2018_sci             1.870114
# sat2018_part_rate      37.314256
# sat2018_erw            47.502627
# sat2018_math           47.772623
# sat2018_total_score    94.155083
# dtype: float64

# %%
# manually calculated standard deviations 

print('Manually calculated standard deviation : ', sd['act2017_part_rate'])
# Out:
# Manually calculated standard deviation :  31.824175751231806

# %%
# numpy's std method

print("Using Numpy's std method' : " , final['act2017_part_rate'].std() )
# Out:
# Using Numpy's std method' :  32.14084201588683

# %%
# output from pandas describe

print('Using pandas describe() table : ', final.describe().transpose().loc['act2017_part_rate','std'])
# Out:
# Using pandas describe() table :  32.14084201588683

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# ### Answer:
#
# - My manually calculated calculated standard deviation is different from pandas describe table.
# - The numpy's std method matches the pandas describe table

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Answer:
#
# - Which states have the highest and lowest participation rates for the:
# - the states are derived by sorting dataframe by column
#     - 2017 SAT?
#       - highest:  District of Columbia, Michigan, Connecticut, Delaware, New Hampshire
#       - lowest:  North Dakota, Mississippi, Iowa, Missouri, Utah
#     - 2018 SAT?
#       - highest: Colorado, Connecticut, Delaware, Michigan, Idaho
#       - lowest:  North Dakota, Wyoming, South Dakota, Nebraska, Wisconsin
#     - 2017 ACT?
#        - highest(all have 100%):  Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Nevada, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado, Arkansas
#        - lowest:  Maine, Rhode Island, New Hampshire, Delaware, Pennsylvania
#     - 2018 ACT?
#        - highest(all have 100%):  Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, Ohio, North Carolina, Nevada, Nebraska, Montana, Mississippi, Louisiana, Missouri, Wyoming, Arkansas
#        - lowest:  Maine, Rhode Island, New Hampshire, Delaware, Pennsylvania
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#        - highest: Minnesota, Wisconsin, Iowa, Missouri, Kansas
#        - lowest: District of Columbia, Delaware, Idaho, Michigan, Maine
#     - 2018 SAT?
#        - highest:  Minnesota, Wisconsin, North Dakota, Iowa, Kansas
#        - lowest:  District of Columbia, Delaware, West Virginia, Idaho, Utah
#     - 2017 ACT?
#       - highest: New Hampshire, Massachusetts, Connecticut, Maine, District of Columbia
#       - lowest: Nevada, Mississippi, South Carolina, Hawaii, North Carolina
#     - 2018 ACT?
#       - highest: Connecticut, Massachusetts, New Hampshire, New York, Michigan
#       - lowest: Nevada, South Carolina, Mississippi, Hawaii, Alabama

# %% [markdown]
# ####  2017 SAT states have the highest participation rates

# %%
# states have the highest participation rates for the 2017 SAT

final[['state','sat2017_part_rate']].sort_values(by='sat2017_part_rate', ascending =False).head()
# Out:
#                    state  sat2017_part_rate
# 8   District of Columbia              100.0
# 22              Michigan              100.0
# 6            Connecticut              100.0
# 7               Delaware              100.0
# 29         New Hampshire               96.0

# %% [markdown]
# ####  2017 SAT states have the lowest participation rates

# %%
# states have the lowest participation rates for the 2017 SAT

final[['state','sat2017_part_rate']].sort_values(by='sat2017_part_rate', ascending =True).head()
# Out:
#            state  sat2017_part_rate
# 34  North Dakota                2.0
# 24   Mississippi                2.0
# 15          Iowa                2.0
# 25      Missouri                3.0
# 44          Utah                3.0

# %% [markdown]
# ####  2018 SAT states have the highest participation rates

# %%
# states have the highest participation rates for the 2018 SAT

final[['state','sat2018_part_rate']].sort_values(by='sat2018_part_rate', ascending =False).head()
# Out:
#           state  sat2018_part_rate
# 5      Colorado              100.0
# 6   Connecticut              100.0
# 7      Delaware              100.0
# 22     Michigan              100.0
# 12        Idaho              100.0

# %% [markdown]
# ####  2018 SAT states have the lowest participation rates

# %%
# states have the lowest participation rates for the 2018 SAT

final[['state','sat2018_part_rate']].sort_values(by='sat2018_part_rate', ascending =True).head(10)
# Out:
#            state  sat2018_part_rate
# 34  North Dakota                2.0
# 50       Wyoming                3.0
# 41  South Dakota                3.0
# 27      Nebraska                3.0
# 49     Wisconsin                3.0
# 24   Mississippi                3.0
# 15          Iowa                3.0
# 44          Utah                4.0
# 23     Minnesota                4.0
# 18     Louisiana                4.0

# %% [markdown]
# ####  2017 ACT states have the highest participation rates

# %%
# states have the highest participation rates for the 2017 ACT

final[['state','act2017_part_rate']].sort_values(by='act2017_part_rate', ascending =False).head(20)
# Out:
#              state  act2017_part_rate
# 0          Alabama              100.0
# 17        Kentucky              100.0
# 49       Wisconsin              100.0
# 44            Utah              100.0
# 42       Tennessee              100.0
# 40  South Carolina              100.0
# 36        Oklahoma              100.0
# 33  North Carolina              100.0
# 28          Nevada              100.0
# 26         Montana              100.0
# 24     Mississippi              100.0
# 23       Minnesota              100.0
# 18       Louisiana              100.0
# 25        Missouri              100.0
# 50         Wyoming              100.0
# 5         Colorado              100.0
# 3         Arkansas              100.0
# 34    North Dakota               98.0
# 13        Illinois               93.0
# 11          Hawaii               90.0

# %% [markdown]
# ####  2017 ACT states have the lowest participation rates

# %%
# states have the lowest participation rates for the 2017 ACT

final[['state','act2017_part_rate']].sort_values(by='act2017_part_rate', ascending =True).head()
# Out:
#             state  act2017_part_rate
# 19          Maine                8.0
# 29  New Hampshire               18.0
# 7        Delaware               18.0
# 39   Rhode Island               21.0
# 38   Pennsylvania               23.0

# %% [markdown]
# #### 2018 ACT states have the highest participation rates

# %%
# states have the highest participation rates for the 2018 ACT

final[['state','act2018_part_rate']].sort_values(by='act2018_part_rate', ascending =False).head(20)
# Out:
#              state  act2018_part_rate
# 0          Alabama              100.0
# 17        Kentucky              100.0
# 49       Wisconsin              100.0
# 44            Utah              100.0
# 42       Tennessee              100.0
# 40  South Carolina              100.0
# 36        Oklahoma              100.0
# 35            Ohio              100.0
# 33  North Carolina              100.0
# 28          Nevada              100.0
# 27        Nebraska              100.0
# 26         Montana              100.0
# 24     Mississippi              100.0
# 18       Louisiana              100.0
# 25        Missouri              100.0
# 50         Wyoming              100.0
# 3         Arkansas              100.0
# 23       Minnesota               99.0
# 34    North Dakota               98.0
# 11          Hawaii               89.0

# %% [markdown]
# #### 2018 ACT states have the lowest participation rates

# %%
# states have the lowest participation rates for the 2018 ACT

final[['state','act2018_part_rate']].sort_values(by='act2018_part_rate', ascending =True).head()
# Out:
#             state  act2018_part_rate
# 19          Maine                7.0
# 39   Rhode Island               15.0
# 29  New Hampshire               16.0
# 7        Delaware               17.0
# 38   Pennsylvania               20.0

# %%
final[(final['act2017_part_rate']==100)&(final['act2018_part_rate']==100)][['state','act2017_part_rate','sat2017_part_rate','act2018_part_rate','sat2018_part_rate']].sort_values(by='sat2018_part_rate', ascending =True).head(10)
# Out:
#           state  act2017_part_rate  sat2017_part_rate  act2018_part_rate  \
# 24  Mississippi              100.0                2.0              100.0
# 49    Wisconsin              100.0                3.0              100.0
# 50      Wyoming              100.0                3.0              100.0
# 17     Kentucky              100.0                4.0              100.0
# 18    Louisiana              100.0                4.0              100.0
# 25     Missouri              100.0                3.0              100.0
# 44         Utah              100.0                3.0              100.0
# 3      Arkansas              100.0                3.0              100.0
# 0       Alabama              100.0                5.0              100.0
# 42    Tennessee              100.0                5.0              100.0
#
#     sat2018_part_rate
# 24                3.0
# 49                3.0
# 50                3.0
# 17                4.0
# 18                4.0
# 25                4.0
# ...

# %%
final[(final['sat2017_part_rate']>=80)&(final['sat2018_part_rate']>=80)][['state','act2017_part_rate','sat2017_part_rate','act2018_part_rate','sat2018_part_rate']].sort_values(by='act2018_part_rate', ascending =True).head(10)
# Out:
#                    state  act2017_part_rate  sat2017_part_rate  \
# 19                 Maine                8.0               95.0
# 29         New Hampshire               18.0               96.0
# 7               Delaware               18.0              100.0
# 22              Michigan               29.0              100.0
# 6            Connecticut               31.0              100.0
# 8   District of Columbia               32.0              100.0
# 12                 Idaho               38.0               93.0
#
#     act2018_part_rate  sat2018_part_rate
# 19                7.0               99.0
# 29               16.0               96.0
# 7                17.0              100.0
# 22               22.0              100.0
# 6                26.0              100.0
# 8                32.0               92.0
# 12               36.0              100.0

# %% [markdown]
# ### SAT 2017 total score highest

# %%
final[['state','sat2017_total_score']].sort_values(by='sat2017_total_score', ascending =False).head()
# Out:
#         state  sat2017_total_score
# 23  Minnesota                 1295
# 49  Wisconsin                 1291
# 15       Iowa                 1275
# 25   Missouri                 1271
# 16     Kansas                 1260

# %% [markdown]
# ### SAT 2017 total score lowest

# %%
final[['state','sat2017_total_score']].sort_values(by='sat2017_total_score', ascending =True).head()
# Out:
#                    state  sat2017_total_score
# 8   District of Columbia                  950
# 7               Delaware                  996
# 12                 Idaho                 1005
# 22              Michigan                 1005
# 19                 Maine                 1012

# %% [markdown]
# ### ACT 2017 composite score highest

# %%
final[['state','act2017_com_score']].sort_values(by='act2017_com_score', ascending =False).head()
# Out:
#                    state  act2017_com_score
# 29         New Hampshire               25.5
# 21         Massachusetts               25.4
# 6            Connecticut               25.2
# 19                 Maine               24.3
# 8   District of Columbia               24.2

# %% [markdown]
# ### ACT 2017 composite score lowest

# %%
final[['state','act2017_com_score']].sort_values(by='act2017_com_score', ascending =True).head()
# Out:
#              state  act2017_com_score
# 28          Nevada               17.8
# 24     Mississippi               18.6
# 40  South Carolina               18.7
# 11          Hawaii               19.0
# 33  North Carolina               19.1

# %% [markdown]
# ### SAT 2018 total score highest

# %%
final[['state','sat2018_total_score']].sort_values(by='sat2018_total_score', ascending =False).head()
# Out:
#            state  sat2018_total_score
# 23     Minnesota                 1298
# 49     Wisconsin                 1294
# 34  North Dakota                 1283
# 15          Iowa                 1265
# 16        Kansas                 1265

# %% [markdown]
# ### SAT 2018 total score lowest

# %%
final[['state','sat2018_total_score']].sort_values(by='sat2018_total_score', ascending =True).head()
# Out:
#                    state  sat2018_total_score
# 8   District of Columbia                  977
# 7               Delaware                  998
# 48         West Virginia                  999
# 12                 Idaho                 1001
# 44                  Utah                 1010

# %% [markdown]
# ### ACT 2018 composite score highest

# %%
final[['state','act2018_com_score']].sort_values(by='act2018_com_score', ascending =False).head()
# Out:
#             state  act2018_com_score
# 6     Connecticut               25.6
# 21  Massachusetts               25.5
# 29  New Hampshire               25.1
# 32       New York               24.5
# 22       Michigan               24.4

# %% [markdown]
# ### ACT 2018 composite score lowest

# %%
final[['state','act2018_com_score']].sort_values(by='act2018_com_score', ascending =True).head()
# Out:
#              state  act2018_com_score
# 28          Nevada               17.7
# 40  South Carolina               18.3
# 24     Mississippi               18.6
# 11          Hawaii               18.9
# 0          Alabama               19.1

# %% [markdown]
# ### Answer
#
# ### Do any states with 100% participation on a given test have a rate change year-to-year?
#
# - SAT: District of Columbia (rate change from 100% in 2017 to 92% in 2018)
# - ACT: Colorado (rate change from 100% in 2017 to 30% in 2018) & Minnesota (rate change from 100% in 2017 to 99% in 2018)

# %%
final[final['sat2017_part_rate'] == 100][['state', 'sat2017_part_rate', 'sat2018_part_rate']]
# Out:
#                    state  sat2017_part_rate  sat2018_part_rate
# 6            Connecticut              100.0              100.0
# 7               Delaware              100.0              100.0
# 8   District of Columbia              100.0               92.0
# 22              Michigan              100.0              100.0

# %%
final[final['act2017_part_rate'] == 100][['state', 'act2017_part_rate', 'act2018_part_rate']]
# Out:
#              state  act2017_part_rate  act2018_part_rate
# 0          Alabama              100.0              100.0
# 3         Arkansas              100.0              100.0
# 5         Colorado              100.0               30.0
# 17        Kentucky              100.0              100.0
# 18       Louisiana              100.0              100.0
# 23       Minnesota              100.0               99.0
# 24     Mississippi              100.0              100.0
# 25        Missouri              100.0              100.0
# 26         Montana              100.0              100.0
# 28          Nevada              100.0              100.0
# 33  North Carolina              100.0              100.0
# 36        Oklahoma              100.0              100.0
# 40  South Carolina              100.0              100.0
# 42       Tennessee              100.0              100.0
# 44            Utah              100.0              100.0
# ...

# %% [markdown]
# ### Answer
#
# ### Do any states show have >50% participation on both tests either year?
# - in year 2017: Florida, Georgia and Hawaii have >50% participation rate for SAT & ACT
# - in year 2018:Florida, Georgia, Hawaii, North Carolina & South Carolina have >50% participation rate for SAT & ACT

# %%
final[(final['sat2017_part_rate'] >50) & (final['act2017_part_rate']>50)][['state','sat2017_part_rate', 'act2017_part_rate']]
# Out:
#       state  sat2017_part_rate  act2017_part_rate
# 9   Florida               83.0               73.0
# 10  Georgia               61.0               55.0
# 11   Hawaii               55.0               90.0

# %%
final[(final['sat2018_part_rate'] >50) & (final['act2018_part_rate']>50)][['state','sat2018_part_rate', 'act2018_part_rate']]
# Out:
#              state  sat2018_part_rate  act2018_part_rate
# 9          Florida               56.0               66.0
# 10         Georgia               70.0               53.0
# 11          Hawaii               56.0               89.0
# 33  North Carolina               52.0              100.0
# 40  South Carolina               55.0              100.0

# %% [markdown]
# ### Answer
#
# ### Interesting states to note
# - Make a note of these and state why you think they're interesting:
#
# #### Interesting states:
#
# 1. Minnesota and Wisconsin have 100% participation rate in ACT 2017 & ACT 2018 but have the lowest participation rate in SAT 2017 & SAT 2018.But the average Total SAT scores in 2017 & 2018 are the highest in USA
#
# 2. Delaware has 100% participation rate in SAT 2017 & SAT 2018 but have the lowest participation rate in ACT 2017 & ACT 2018. But the average Total SAT scores in 2017 & 2018 are the lowest in USA.
#
# 3. Connecticut has 100% participation rate in SAT 2017 & 2018. Connecticut has the lowest participation rate in ACT 2017 & ACT 2018 but produced one of the highest scores for ACT 2017 & 2018.
#
# ### Observations
#  - A. For states that have high participation rate in SAT, they will have low participation rate in ACT. and vice versa for other states
#  - B. States that show low participation rate, they achieve higher scores in the same test.
#
# - States like Minnesota and Wiscosin are states that incorporate ACT in their mandatory testing program but not SAT. Students who voluntarily participate in SAT will be a small percentage of the state. They could be students looking to improve their college applications and are likely to study & do well in SAT. Hence higher scores.
#
# - States like Delaware and Connecticut are contracted with the College Board to administer the SAT for free. As all students are tested, there will be students not applying to college and overall scores will be lower.
#
# ### Source:
# - [Website 1](https://www.washingtonpost.com/blogs/govbeat/wp/2013/09/26/the-midwest-is-really-good-at-the-sats/)
# - [Website 2](https://www.startribune.com/minnesota-s-act-scores-remain-tops-among-states-where-most-take-the-test/564076332/)

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(14,14))
sns.heatmap(final.corr(), vmax=.5, vmin=0, square=True, annot=True, cmap='BuPu')
plt.title('Heatmap of ACT & SAT test scores and Participate rates in 2017 & 2018');

# %% [markdown]
# Observation from heatmap:
# - Based on the heatmap colorbar:
#     - dark colors show the strong negative correlation between ACT participation rate and ACT scores
#     - dark colors show the strong negative correlation between SAT participation rate and SAT scores
#     - light colors show the strong positive correlation between ACT participation rate and SAT scores
#     - light colors show the strong positive correlation between SAT participation rate and ACT scores

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(12,12)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins='auto', color='blue', alpha=0.5) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylabel(list_of_ylabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
list_of_part = ['act2017_part_rate', 'sat2017_part_rate', 'act2018_part_rate', 'sat2018_part_rate']
part_title = ['ACT 2017 participation rate', 'SAT 2017 participation rate', 'ACT 2018 participation rate', 'SAT 2018 participation rate']
part_xlabel= ['% of participation', '% of participation', '% of participation', '% of participation']
part_ylabel=['Frequency of States', 'Frequency of States', 'Frequency of States', 'Frequency of States']

subplot_histograms(final, list_of_part, part_title, part_xlabel,part_ylabel)

# %% [markdown]
# #### Participation rates for SAT & ACT histograms Interpretations
# - ACT 2017 participation rate histogram: it has left-skewed distribution shape with 3 peaks and a mode estimated around 90% to 100% of participation.
# - SAT 2017 participation rate histogram: it has right-skewed distribution shape with 3 peaks and a mode estimated around 0% to 10% of participation.
# - ACT 2018 participation rate histogram: it has left-skewed distribution shape with 3 peaks and a mode estimated around 90% to 100% of participation.
# - SAT 2018 participation rate histogram: it has right-skewed distribution shape with 3 peaks and a mode estimated around 0% to 10% of participation.
#
# This indicates ACT2017 and ACT2018 show highest frequency of states based on mode to have high participation rates (estimated 90 to 100%)
# This indicates SAT2017 and SAT2018 show highest frequency of states based on mode to have low participation rates (estimated 0 to 10%)

# %%
Math_scores_list = ['act2017_math', 'sat2017_math', 'act2018_math', 'sat2018_math']
Math_scores_title=['ACT 2017 Math Scores', 'SAT 2017 Math Scores', 'ACT 2018 Math Scores', 'SAT 2018 Math Scores']
Math_scores_xlabel=['Scores', 'Scores','Scores','Scores']
ylabel=['Frequency of States', 'Frequency of States', 'Frequency of States', 'Frequency of States']

subplot_histograms(final,Math_scores_list, Math_scores_title, Math_scores_xlabel, ylabel)

# %% [markdown]
# #### Math scores for SAT & ACT histograms  Interpretations
# - ACT 2017 Math Scores histogram: it has a right-skewed distribution shape with 3 peaks and a mode estimated around 19 to 20 score.
# - SAT 2017 Math Scores histogram: it has a right-skewed distribution shape with 2 peaks and a mode estimated around 525 to 550 score.
# - ACT 2018 Math Scores histogram: it has a right-skewed distribution shape with 2 peaks and a mode estimated around 19 to 20 score.
# - SAT 2018 Math Scores histogram: it has a right-skewed distribution shape with 2 peaks and a mode estimated around 525 to 550 score.
#
# This indicates that the mode score(between 19 to 20) for ACT2017 and ACT2018 did not change much.
# This indicate that the mode score(between 525 to 550) for SAT2017 and SAT2018 did not change much.
# As all of the above histograms are right-skewed, this indicates highest frequency of states (where the mode is) is lesser than the median and mean scores

# %%
Reading_scores_list = ['act2017_read', 'sat2017_erw', 'act2018_read', 'sat2018_erw']
Reading_scores_title=['ACT 2017 Reading Scores', 'SAT 2017 ERW Scores', 'ACT 2018 Reading Scores', 'SAT 2018 ERW Scores']
Reading_scores_xlabel=['Scores', 'Scores','Scores','Scores']
ylabel=['Frequency of States', 'Frequency of States', 'Frequency of States', 'Frequency of States']

subplot_histograms(final,Reading_scores_list, Reading_scores_title,Reading_scores_xlabel, ylabel)

# %% [markdown]
# ### Reading/verbal scores for SAT & ACT histograms Interpretations
# - ACT 2017 Reading Scores histogram: it has a right-skewed distribution shape with 2 peaks with a mode estimated around 20.5 to 21.5 score.
# - SAT 2017 ERW Scores histogram: it has a right-skewed distribution shape with 2 peaks with a mode estimated around 530 to 550 score(15 states).
# - ACT 2018 Reading Scores histogram: it has a right-skewed distribution shape with 2 peaks with a mode estimated around 20.5 to 21.5 score.
# - SAT 2018 ERW Scores histogram: it has a distribution shape with 2 peaks, the 2 modes seem to have a same frequency(12 states each). The first is estimated around 530 to 550 score and the second is around 620 to 640 score.
#
# ### Interpretations
#  A. This indicates that the mode score(between 20.5 to 21) for ACT2017 and ACT2018 did not change.
#  - For Reading/verbal scores ACT2017 & 2018, as they are right-skewed, this indicates highest frequency of states (where the mode is) is lesser than the median and mean scores
#
# B. This indicates that the mode score(between 530 to 550) for SAT2017(15 states) changed to 2 modes: (530 to 550) and (620 to 640) for SAT2018(12 states each)
#  - This may indicate an improvement in ERW scores for some states from SAT2017 to SAT2018.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def scatterplot(x,y):
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=final, x=x, y=y, size='sat2017_part_rate',sizes=(40,300), palette='muted', alpha=0.4);
    plt.title(f'Scatterplot of {x} vs {y}')
    plt.legend(loc='best', borderpad=0.8, labelspacing=1)

# %%
#1 SAT vs. ACT math scores for 2017 ==> 'sat2017_math' vs 'act2017_math'
scatterplot('sat2017_math','act2017_math')
plt.xlabel('SAT2017 Math Scores')
plt.ylabel('ACT2017 Math Scores');

# %% [markdown]
# ### Interpretation of Scatterplot of SAT2017 Math Scores vs ACT2017 Math Scores
#
# - The datapoints are spread out in the scatterplot, as it does not resemble any pattern it indicates a weak or no relationship between SAT2017 Math Scores and ACT2017 Math Scores.
# - The SAT 2017 Participation rate is a continuous variable which is mapped to size. The larger the size, the higher the SAT 2017 Participation rate.
# - SAT 2017 Participation rate is higher at higher ACT2017 Math Scores and at lower SAT2017 Math Scores

# %%
#2 SAT vs. ACT verbal/reading scores for 2017 ==> 'sat2017_erw' vs 'act2017_read'
scatterplot('sat2017_erw', 'act2017_read')
plt.xlabel('SAT2017 ERW Scores')
plt.ylabel('ACT2017 Read Scores');

# %% [markdown]
# ### Interpretation of Scatterplot of SAT2017 ERW Scores vs ACT2017 Read Scores:
# - The datapoints are spread out in the scatterplot, as it does not resemble any pattern it indicates a weak or no relationship between SAT2017 ERW Scores and ACT2017 Read Scores.
# - The SAT 2017 Participation rate is a continuous variable which is mapped to size. The larger the size, the higher the SAT 2017 Participation rate.
# - SAT 2017 Participation rate is higher at lower SAT2017 ERW Scores and higher ACT2017 Read Scores.

# %%
#3 SAT vs. ACT total/composite scores for 2017 ==> 'sat2017_total_score' vs 'act2017_com_score'

scatterplot('sat2017_total_score', 'act2017_com_score')
plt.xlabel('SAT2017 Total Scores')
plt.ylabel('ACT2017 Composition Scores');

# %% [markdown]
# ### Interpretation of Scatterplot of SAT2017 Total Scores vs ACT2017 Composition Scores:
# - The datapoints are spread out in the scatterplot, as it does not resemble any pattern it indicates a weak or no relationship between SAT2017 Total Scores and ACT2017 Composition Scores.
# - The SAT2017 Participation rate is a continuous variable which is mapped to size. The larger the size, the higher the SAT2017 Participation rate.
# - SAT2017 Participation rate is higher at lower SAT2017 Total Scores and at higher ACT2017 Composition Scores.

# %%
#4 Total scores for SAT 2017 vs. 2018 ==> 'sat2017_total_score' vs 'sat2018_total_score'

scatterplot('sat2017_total_score', 'sat2018_total_score')
plt.xlabel('SAT2017 Total Scores')
plt.ylabel('SAT2018 Total Scores');

# %% [markdown]
# ### Interpretation of Scatterplot of SAT2017 Total Scores vs SAT2018 Total Scores:
# - Even though there are some datapoints that are outliers,many datapoints lie close together in a positive linear direction.  This indicates a positive correlation between SAT2017 Total Scores and SAT2018 Total Scores.
# - The SAT2017 Participation rate is a continuous variable which is mapped to size. The larger the size, the higher the SAT2017 Participation rate.
# - SAT2017 Participation rate is higher at lower SAT2017 Total Scores and lower SAT2018 Total Scores.

# %%
#5 Composite scores for ACT 2017 vs. 2018 ==> 'act2017_com_score' vs 'act2018_com_score'

scatterplot('act2017_com_score', 'act2018_com_score')
plt.xlabel('ACT2017 Composite Scores')
plt.ylabel('ACT2018 Composite Scores');

# %% [markdown]
# ### Interpretation of Scatterplot of ACT2017 Composite Scores vs ACT2018 Composite Scores:
# - Even though there are some datapoints that are outliers,many datapoints lie close together in a positive linear direction.  This indicates a positive relationship between ACT2017 Composite Scores and ACT2018 Composite Scores.
# - The SAT2017 Participation rate is a continuous variable which is mapped to size. The larger the size, the higher the SAT2017 Participation rate.
# - higher SAT2017 Participation rate can be observed on the lower and higher ACT scores, but there are more datapoints with higher SAT2017 participation rate with higher ACT scores.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
#sns.boxplot(x=['act2017_part_rate','sat2017_part_rate'],data=final)

plt.figure(figsize=(8,4))
seaborn_df = pd.DataFrame(data=final, columns =['act2017_part_rate','sat2017_part_rate', 'act2018_part_rate','sat2018_part_rate'] )
sns.boxplot(x="variable", y="value", data=pd.melt(seaborn_df), palette ='rainbow',width=0.5);
plt.title('Boxplot of Participation rates by ACT & SAT tests in 2017 & 2018')
plt.xlabel('Tests')
plt.ylabel('Participation %');

# %% [markdown]
# #### Participation rates in 2017 and 2018 boxplot interpretation:
#
# - Based on the boxplot, the median for ACT2017 and ACT2018 Participation rates are higher than SAT2017 and SAT2018 Participation rates.
# - Also, the Interquartile range for ACT2017 and ACT2018 Participation rates are estimated to be in the range of 30% to 100% and higher than the Interquartile range for SAT2017(estimated range of 0 to 70%) and SAT2018 Participation rates (estimated range of 0 to 80%).

# %%
plt.figure(figsize=(18,6))

seaborn_df_act = pd.DataFrame(data=final, columns = ['act2017_eng', 'act2017_math','act2017_read', 'act2017_sci', 'act2017_com_score',
                                                 'act2018_eng', 'act2018_math','act2018_read', 'act2018_sci', 'act2018_com_score'])
                          
sns.boxplot(x="variable", y="value", data=pd.melt(seaborn_df_act), palette ='rainbow',width=0.5)   
plt.title('Boxplot of Scores by ACT tests in 2017 & 2018')
plt.xlabel('ACT Tests')
plt.ylabel('Scores');

# %% [markdown]
# #### ACT test scores in 2017 and 2018 boxplot interpretation:
#
# - Based on the boxplot, the median ACT test scores in 2017 and 2018 are similar.
# - The Interquartile range for ACT test scores are also similar in the estimated range of 19 to 24.
# - The whiskers for act2017_eng (ACT2017 English) and act2018_eng (ACT2018 English) are longer than the other ACT test scores.
# - Based on the whiskers, act2017_eng has an estimated minimum score of 16 to maximum score of 25 and act2018_eng has a estimated minimum score of 16 to maximum score of 26.
# - This implies more spread in variables for act2017_eng and act2018_eng

# %%
plt.figure(figsize=(8,4))
seaborn_df_sat = pd.DataFrame(data=final, columns =['sat2017_erw', 'sat2017_math','sat2018_erw','sat2018_math'] )
sns.boxplot(x="variable", y="value", data=pd.melt(seaborn_df_sat), palette ='rainbow',width=0.5);
plt.title('Boxplot of Scores by SAT tests in 2017 & 2018')
plt.xlabel('SAT Tests')
plt.ylabel('Scores');

# %% [markdown]
# #### SAT test scores in 2017 and 2018 boxplot interpretation:
#
# - Based on the boxplot, the median SAT test scores in 2017 and 2018 are similar.
# - The Interquartile range for Math SAT scores(2017 and 2018) are estimated between 525 and 600, lower than the Interquartile range for Math ERW scores(2017 and 2018) between 530 and 610.
# - The whiskers for Math SAT scores(2017 and 2018) are longer than Math ERW scores(2017 and 2018).
# - The whiskers for Math SAT scores(2017 and 2018) are estimated between minimum score of 475 and maximum score of 650.
# - This implies more spread in variables for Math SAT scores(2017 and 2018)

# %%
plt.figure(figsize=(8,4))
seaborn_df_sat_total = pd.DataFrame(data=final, columns =[ 'sat2017_total_score', 'sat2018_total_score'] )
sns.boxplot(x="variable", y="value", data=pd.melt(seaborn_df_sat_total), palette ='rainbow',width=0.5);
plt.title('Boxplot of Scores by SAT total scores in 2017 & 2018')
plt.xlabel('SAT Test Total Scores')
plt.ylabel('Scores');

# %% [markdown]
# ### SAT test scores in 2017 and 2018 boxplot interpretation:
# - Based on the boxplot, the median SAT Total scores in 2017 and 2018 are similar.
# - The Interquartile range for SAT Total scores in 2017 and 2018 are similar estimated between the range of 1050 and 1210
# - The whiskers for SAT Total scores in 2017 and 2018 are also similar estimated between minimum score of 950 and maximum score of 1300

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,6), sharey=True, sharex=True)
sns.distplot(final['act2017_part_rate'], ax=ax[0], color='blue', bins=5, label='ACT2017 Participation rate')
sns.distplot(final['sat2017_part_rate'], ax=ax[0], color='orange', bins=5, label='SAT2017 Participation rate')
ax[0].legend()
ax[0].set_title('Histogram of ACT & SAT Participation rates in 2017')
ax[0].set_ylabel('Frequency')
ax[0].set_xlabel('Participation rates %')

sns.distplot(final['act2018_part_rate'], ax=ax[1], color='blue', bins=5, label='ACT2018 Participation rate')
sns.distplot(final['sat2018_part_rate'], ax=ax[1], color='orange', bins=5, label='SAT2018 Participation rate')
ax[1].legend()
ax[1].set_title('Histogram of ACT & SAT Participation rates in 2018')
ax[1].set_xlabel('Participation rates %');

# %% [markdown]
# #### Histogram of ACT & SAT Participation rates in 2017 and 2018 Interpretation:
# This indicate that highest frequency of states which is the mode show low SAT participation(estimated 0% to 10%) compared to ACT participation(estimated 90% to 100%) for both year 2017 & 2018

# %%
def regplotsub(x1,y1, x2, y2):
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,6))
    sns.regplot(data=final, x=x1, y=y1, ax=ax[0])
    ax[0].set_title(f'regplot of {x1} vs {y1}')
    ax[0].set_ylabel(y1)
    ax[0].set_xlabel(x1)

    sns.regplot(data=final, x=x2, y=y2, ax=ax[1])
    ax[1].set_title(f'regplot of {x2} vs {y2}')
    ax[1].set_ylabel(y2)
    ax[1].set_xlabel(x2)

# %%
regplotsub('act2017_part_rate','sat2017_part_rate','act2018_part_rate','sat2018_part_rate')

# %% [markdown]
# ### sns.regplot of Total Scores vs Participation rate for SAT 2017 & 2018 interpretation
#
# Many datapoints are scattered in a negative linear direction, this indicates the ACT Participation rate and SAT Participation rate have a negative correlation. The higher the Participation rate in ACT2017 & ACT2018, the lower the Participation rate in SAT2017 & SAT2018.

# %%
regplotsub('sat2017_total_score','sat2017_part_rate','sat2018_total_score','sat2018_part_rate')

# %% [markdown]
# ### sns.regplot of Total Scores vs Participation rate for SAT 2017 & 2018 interpretation
#
# Many datapoints are scattered in a negative linear direction, this indicates the SAT Total Scores and SAT Participation rate have a negative correlation.
# The higher the Total Scores in SAT2017 & SAT2018, the lower the Participation rate in SAT2017 & SAT2018.

# %%
regplotsub('act2017_com_score','act2017_part_rate','act2018_com_score','act2018_part_rate')

# %% [markdown]
# ### sns.regplot of Composite Scores vs Participation rate for ACT 2017 & 2018 interpretation
#
# Many datapoints are in a negative linear direction, this indicates the ACT Composite Scores and ACT Participation rate have a negative correlation.
# The higher the Composite Scores in ACT2017 & ACT2018, the lower the Participation rate in ACT2017 & ACT2018.

# %%
regplotsub('sat2017_total_score','act2017_part_rate','sat2018_total_score','act2018_part_rate')

# %% [markdown]
# ### sns.regplot of SAT Total Scores vs Participation rate for ACT in 2017 & 2018 interpretation
#
# Many datapoints are in a positive linear direction, this indicates the SAT Scores and ACT Participation rate have a positive correlation

# %%
regplotsub('act2017_com_score','sat2017_part_rate','act2018_com_score','sat2018_part_rate')

# %% [markdown]
# ### sns.regplot of ACT Composite Scores vs Participation rate for SAT in 2017 & 2018 interpretation
#
# Many datapoints are in a positive linear direction, this indicates the ACT Scores and SAT Participation rate have a positive correlation

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# <img src="tableaumap.png" style="width:650px;height:350px">

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
def create_distplot_with_mean_median(x):
    plt.figure(figsize=(8,6))
    ax = sns.distplot(final[x], color='skyblue', kde=True, bins='auto')
    kdeline = ax.lines[0]
    xs = kdeline.get_xdata()
    ys = kdeline.get_ydata()
    cal_mean = final[x].mean()
    cal_median = final[x].median()
    meanheight = np.interp(cal_mean,xs, ys)
    ax.vlines(cal_mean, 0, meanheight, color='red', ls=':', label='estimated mean = ' + str(round(cal_mean,2)))
    medheight = np.interp(cal_median, xs, ys)
    ax.vlines(cal_median, 0, medheight, color='orange', ls='-', label='estimated median = ' + str(round(cal_median,2)))
    plt.legend(loc='best')
    plt.title(f'Histogram of {x}')
    plt.xlabel(x)
    print(f'In Histogram of {x}, the estimated mean is {round(cal_mean,2)} and the estimated median is {round(cal_median,2)}')
    if cal_mean > cal_median:
        print('As the estimated mean is higher than the estimated median,')
        print('The distribution is skewed and based on the shape of the histogram it is Right Skewed.')
    elif cal_mean < cal_median:
        print('As the estimated mean is lower than the estimated median,')
        print('The distribution is skewed and based on the shape of the histogram it is Left Skewed.')
    elif cal_mean == cal_median:
        print('The estimated mean is equal to estimated median') #not god so will not happen
        
# Note:
# kde is kernel density estimation
# only based on 51 states/observation
# kde dont perform well at boundaries

# %%
#1 

create_distplot_with_mean_median('act2017_part_rate')
# Out:
# In Histogram of act2017_part_rate, the estimated mean is 65.25 and the estimated median is 69.0
# As the estimated mean is lower than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Left Skewed.

# %%
#2 
create_distplot_with_mean_median('act2017_eng')
# Out:
# In Histogram of act2017_eng, the estimated mean is 20.93 and the estimated median is 20.7
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#3 
create_distplot_with_mean_median('act2017_math')
# Out:
# In Histogram of act2017_math, the estimated mean is 21.18 and the estimated median is 20.9
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#4 
create_distplot_with_mean_median('act2017_read')
# Out:
# In Histogram of act2017_read, the estimated mean is 22.01 and the estimated median is 21.8
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#5 
create_distplot_with_mean_median('act2017_sci')
# Out:
# In Histogram of act2017_sci, the estimated mean is 21.45 and the estimated median is 21.3
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#6 
create_distplot_with_mean_median('act2017_com_score')
# Out:
# In Histogram of act2017_com_score, the estimated mean is 21.52 and the estimated median is 21.4
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#7 
create_distplot_with_mean_median('sat2017_part_rate')
# Out:
# In Histogram of sat2017_part_rate, the estimated mean is 39.8 and the estimated median is 38.0
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#8 
create_distplot_with_mean_median('sat2017_erw')
# Out:
# In Histogram of sat2017_erw, the estimated mean is 569.12 and the estimated median is 559.0
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#9 
create_distplot_with_mean_median('sat2017_math')
# Out:
# In Histogram of sat2017_math, the estimated mean is 556.88 and the estimated median is 548.0
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#10 
create_distplot_with_mean_median('sat2017_total_score')
# Out:
# In Histogram of sat2017_total_score, the estimated mean is 1126.1 and the estimated median is 1107.0
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#11 
create_distplot_with_mean_median('act2018_part_rate')
# Out:
# In Histogram of act2018_part_rate, the estimated mean is 61.65 and the estimated median is 66.0
# As the estimated mean is lower than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Left Skewed.

# %%
#12 
create_distplot_with_mean_median('act2018_com_score')
# Out:
# In Histogram of act2018_com_score, the estimated mean is 21.49 and the estimated median is 21.3
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#13 
create_distplot_with_mean_median('act2018_eng')
# Out:
# In Histogram of act2018_eng, the estimated mean is 20.99 and the estimated median is 20.2
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#14 
create_distplot_with_mean_median('act2018_math')
# Out:
# In Histogram of act2018_math, the estimated mean is 21.13 and the estimated median is 20.7
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#15 
create_distplot_with_mean_median('act2018_read')
# Out:
# In Histogram of act2018_read, the estimated mean is 22.02 and the estimated median is 21.6
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#16 
create_distplot_with_mean_median('act2018_sci')
# Out:
# In Histogram of act2018_sci, the estimated mean is 21.35 and the estimated median is 21.1
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#17 
create_distplot_with_mean_median('sat2018_part_rate')
# Out:
# In Histogram of sat2018_part_rate, the estimated mean is 45.75 and the estimated median is 52.0
# As the estimated mean is lower than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Left Skewed.

# %%
#18 
create_distplot_with_mean_median('sat2018_erw')
# Out:
# In Histogram of sat2018_erw, the estimated mean is 563.69 and the estimated median is 552.0
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#19 
create_distplot_with_mean_median('sat2018_math')
# Out:
# In Histogram of sat2018_math, the estimated mean is 556.24 and the estimated median is 544.0
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %%
#20 
create_distplot_with_mean_median('sat2018_total_score')
# Out:
# In Histogram of sat2018_total_score, the estimated mean is 1120.02 and the estimated median is 1098.0
# As the estimated mean is higher than the estimated median,
# The distribution is skewed and based on the shape of the histogram it is Right Skewed.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: We do not observe this trend as the above distplots for all of the numerical variables from this dataset are skewed.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
def subplot_dist(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(10,10))
    ax = ax.ravel()
    for i, column in enumerate(list_of_columns): 
        sns.distplot(dataframe[column], ax=ax[i], bins='auto', color='blue')
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])

# %%
# math

Math_scores_list = ['act2017_math', 'sat2017_math', 'act2018_math', 'sat2018_math']
Math_scores_title= Math_scores_list
Math_scores_xlabel=['Scores', 'Scores','Scores','Scores']

subplot_dist(final,Math_scores_list, Math_scores_title, Math_scores_xlabel)

# %%
# reading
Reading_scores_list = ['act2017_read', 'sat2017_erw', 'act2018_read', 'sat2018_erw']
Reading_scores_title= Reading_scores_list
Reading_scores_xlabel=['Scores', 'Scores','Scores','Scores']


subplot_dist(final,Reading_scores_list, Reading_scores_title,Reading_scores_xlabel)

# %%
# participation rates
list_of_part = ['act2017_part_rate', 'sat2017_part_rate', 'act2018_part_rate', 'sat2018_part_rate']
part_title = list_of_part
part_xlabel= ['% of participation', '% of participation', '% of participation', '% of participation']

subplot_dist(final, list_of_part, part_title, part_xlabel)

# %% [markdown]
# Does This Assumption Hold for:
#
# - Math
# - Reading
# - Rates
#
# Explain your answers for each distribution and how you think this will affect estimates made from these data.
#
# - Math: as per the above subplots for Math scores, the distributions are skewed.
# - Reading: as per the above subplots for Reading, the distributions are skewed.
# - Rates: as the above subplots for Participation rates, the distributions are skewed.
#
# **This will affect estimates made from the data, they also be skewed.**

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %%
final.loc[(final['state']=='California')|(final['state']=='Alabama')|(final['state']=='Arkansas')][['state','act2017_part_rate','act2018_part_rate']]
# Out:
#         state  act2017_part_rate  act2018_part_rate
# 0     Alabama              100.0              100.0
# 3    Arkansas              100.0              100.0
# 4  California               31.0               27.0

# %% [markdown]
# **Answer:**
# - It does not make sense to conduct statistical inference on these data specifically.
# - This is because data is very small and the statistical inference might be highly unreliable.
# - There are only 51 states participating in SAT and ACT.
# - The data is collected only over 2 years,it would be better to collect data from more years
# - The data collected on the average scores and participation rates are based on the States.
# - Some States have higher populations so their Participation rate and scores are averaged out over a larger population.
# - For example California population size is many times larger than Alabama or Arkansas, 31% ACT 2017 participation does not necessarily mean the actual population taking ACT 2017 in California is lesser than Alabama or Arkansas

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %%
final[['act2017_math', 'sat2017_math', 'act2018_math', 'sat2018_math']].describe()
# Out:
#        act2017_math  sat2017_math  act2018_math  sat2018_math
# count     51.000000     51.000000     51.000000     51.000000
# mean      21.182353    556.882353     21.125490    556.235294
# std        1.981989     47.121395      2.035765     47.772623
# min       18.000000    468.000000     17.800000    480.000000
# 25%       19.400000    523.500000     19.400000    522.500000
# 50%       20.900000    548.000000     20.700000    544.000000
# 75%       23.100000    599.000000     23.150000    593.500000
# max       25.300000    651.000000     25.200000    655.000000

# %% [markdown]
# **Answer:**
#
# As per the describe() table above, SAT and ACT math scores are of different relative scale. They do not have similar min/max values, it is not appropriate to compare SAT and ACT math scores.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
# find the difference in SAT participation from 2017 to 2018
final['SAT participation improve'] = final['sat2018_part_rate'] - final['sat2017_part_rate']

# %%
# find top states with the highest improvement in SAT participations
final[['state','sat2017_part_rate', 'SAT participation improve', 'sat2018_part_rate']].sort_values(by='SAT participation improve', ascending= False).head(10)
# Out:
#             state  sat2017_part_rate  SAT participation improve  \
# 13       Illinois                9.0                       90.0
# 5        Colorado               11.0                       89.0
# 39   Rhode Island               71.0                       26.0
# 48  West Virginia               14.0                       14.0
# 30     New Jersey               70.0                       12.0
# 32       New York               67.0                       12.0
# 10        Georgia               61.0                        9.0
# 12          Idaho               93.0                        7.0
# 20       Maryland               69.0                        7.0
# 4      California               53.0                        7.0
#
#     sat2018_part_rate
# 13               99.0
# 5               100.0
# 39               97.0
# 48               28.0
# 30               82.0
# 32               79.0
# 10               70.0
# 12              100.0
# 20               76.0
# 4                60.0

# %%
# just plot top 10 states improvement
top10_improve= final[['state','sat2017_part_rate', 'SAT participation improve', 'sat2018_part_rate']].sort_values(by='SAT participation improve', ascending= False).head(10)

# %%
# plot barplot to show the improvement for 10 states
plt.figure(figsize=(12,6))
sns.barplot(top10_improve['state'], top10_improve['SAT participation improve'], palette='rainbow', alpha=0.6)
plt.title('10 states with largest improvement in SAT participation rates from 2017 to 2018')
plt.xlabel('States')
plt.ylabel('SAT participation rate increase difference %')
plt.title('10 states with largest improvement in SAT participation% in 2017 to 2018');

# %%
# plot the bar chart to compare the participation rates for 2017 to 2018
plt.figure(figsize=(18,6))
top10_improve.plot(x='state', y=['sat2017_part_rate', 'sat2018_part_rate'], kind='bar', colormap='tab20_r', figsize=(12,6) )
plt.xlabel('States')
plt.ylabel('SAT participation rate %')
plt.title('SAT participation% in 2017 & 2018');

# %% [markdown]
# - Colorado, Illinois and Rhode island show the largest increase in SAT participation rate from 2017 to 2018(near 100%), per above bar plots.
# - In 2018, SAT was made mandatory and free in these states.
# - Hence every student attending high school are required to participate and this explains the near 100% participation in 2018
#
# Source:
#
# - [illinois news article 1](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
# - [illinois article 2](https://www.testive.com/illinois/)
# - [colorado article 1](https://www.testive.com/colorado-sat-change-2017/)
# - [illinois article 2](https://www.providencejournal.com/news/20181025/with-sat-required-ri-sees-jump-in-participation-decline-in-scores)

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# **Key takeaways:**
# 1. States that show 100% SAT participation in 2017 and 2018 have mandated statewide SAT testing.
# 2. States like Colorado, Illinois and Rhode island showed increase to near 100% 2018 SAT participation as it became compulsory for students to take SAT in 2018.
# 3. SAT Total Scores and SAT Participation rate have a negative correlation. One possible reason is because statewide testing includes all students and all of them may not be applying to college.
#
# **Recommendations:**
# 1. Encourage states to make SAT a statewide testing requirement. When SAT is a compulsory requirement and is free, participation rates will increase.
# 2. Promote SAT School Day([Website Source](https://collegereadiness.collegeboard.org/sat/k12-educators/sat-school-day/about)) to improve SAT participation rates even if the state is not mandated to take this test. The SAT School Day is convenient for students to take the test in school on a weekday than and provides free tests to low-income students.
# 3. Market SAT as an additional test for College-bound students increase their competitiveness in college applications.
#
# **Suggestion:**
# 1. For North Dakota with the lowest SAT participation rates in 2017 and 2018.
# - Researched online and found that SAT is not compulsory in North Dakota in 2021 too ([Website Source](https://www.testive.com/state-sat-act/)).
# 2. Promote SAT School Day to improve SAT participation rates even if the state is not mandated to take this test.
# 3. Market SAT as an additional test for College-bound students increase their competitiveness in college applications.
#
# **Additional Data to better inform investigations:**
# 1. The actual population taking SAT tests instead of the state participation rate percentage
# 2. Data taken from more years instead 2017 & 2018.
